# %% [markdown]
# # EEG Group Analysis
#
# This notebook loads preprocessed data, parses event files, creates epochs, computes grand averages, and visualizes ERP components.

# %%
# %run ./group_analysis.py
# Out:
# Loading cleaned raw for sub-02, ses-EMS
# Opening raw data file bids_derivatives/sub-02/ses-EMS/eeg/sub-02_ses-EMS_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 129016 =      0.000 ...   516.064 secs
# Ready.
# Reading 0 ... 129016  =      0.000 ...   516.064 secs...
# Not setting metadata
# 200 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 200 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 39 epochs: 4, 16, 17, 26, 27, 30, 31, 50, 51, 78, 79, 80, 81, 86, 87, 100, 101, 102, 103, 104, 105, 106, 107, 122, 123, 126, 127, 130, 131, 132, 133, 138, 139, 156, 157, 180, 181, 186, 187
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Loading cleaned raw for sub-02, ses-Vibro
# Opening raw data file bids_derivatives/sub-02/ses-Vibro/eeg/sub-02_ses-Vibro_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 419385 =      0.000 ...  1677.540 secs
# Ready.
# Reading 0 ... 419385  =      0.000 ...  1677.540 secs...
# Multiple event values for single event times found. Keeping the first occurrence and dropping all others.
# Not setting metadata
# 355 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 355 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 71 epochs: 116, 117, 118, 123, 128, 129, 130, 131, 145, 156, 163, 169, 176, 178, 189, 190, 191, 197, 226, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 249, 262, 264, 268, 269, 271, 272, 277, 288, 293, 294, 298, 302, 303, 304, 307, 309, 317, 318, 319, 321, 322, 323, 324, 325, 326, 327, 331, 332, 333, 334, 335, 336, 337, 341, 345, 346, 347, 348, 349, 350
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Loading cleaned raw for sub-02, ses-Visual
# Opening raw data file bids_derivatives/sub-02/ses-Visual/eeg/sub-02_ses-Visual_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 479545 =      0.000 ...  1918.180 secs
# Ready.
# Reading 0 ... 479545  =      0.000 ...  1918.180 secs...
# Not setting metadata
# 300 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 60 epochs: 0, 7, 10, 12, 13, 16, 18, 21, 22, 23, 26, 28, 30, 40, 55, 58, 68, 72, 76, 77, 84, 100, 101, 102, 103, 107, 108, 109, 110, 113, 114, 117, 122, 132, 143, 162, 170, 200, 201, 203, 204, 205, 208, 209, 210, 211, 213, 221, 222, 226, 231, 233, 238, 240, 252, 255, 257, 268, 279, 281
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Loading cleaned raw for sub-06, ses-EMS
# Opening raw data file bids_derivatives/sub-06/ses-EMS/eeg/sub-06_ses-EMS_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 173681 =      0.000 ...   694.724 secs
# Ready.
# Reading 0 ... 173681  =      0.000 ...   694.724 secs...
# Not setting metadata
# 206 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 206 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 41 epochs: 2, 3, 4, 5, 6, 7, 8, 9, 34, 35, 38, 39, 42, 43, 58, 59, 60, 61, 69, 82, 83, 88, 89, 102, 103, 108, 109, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 148, 149
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Loading cleaned raw for sub-06, ses-Vibro
# Opening raw data file bids_derivatives/sub-06/ses-Vibro/eeg/sub-06_ses-Vibro_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 466491 =      0.000 ...  1865.964 secs
# Ready.
# Reading 0 ... 466491  =      0.000 ...  1865.964 secs...
# Multiple event values for single event times found. Keeping the first occurrence and dropping all others.
# Not setting metadata
# 342 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 342 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 69 epochs: 0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 21, 23, 26, 27, 28, 29, 31, 32, 33, 36, 39, 41, 67, 78, 107, 108, 111, 115, 116, 117, 118, 119, 123, 139, 152, 154, 155, 178, 183, 203, 205, 206, 208, 211, 221, 225, 229, 232, 236, 244, 259, 260, 261, 267, 275, 290, 296, 297, 300, 303, 306, 307, 309, 312, 313, 315, 329, 337
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Loading cleaned raw for sub-06, ses-Visual
# Opening raw data file bids_derivatives/sub-06/ses-Visual/eeg/sub-06_ses-Visual_task-PredictionError_proc-icaclean_raw.fif...
#     Range : 0 ... 640784 =      0.000 ...  2563.136 secs
# Ready.
# Reading 0 ... 640784  =      0.000 ...  2563.136 secs...
# Not setting metadata
# 300 matching events found
# Setting baseline interval to [-0.3, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 0 bad epochs dropped
# Dropped 60 epochs: 2, 102, 105, 119, 120, 121, 122, 123, 128, 131, 133, 134, 135, 136, 138, 139, 140, 145, 147, 148, 150, 151, 153, 154, 155, 158, 159, 160, 161, 163, 164, 165, 171, 172, 173, 174, 175, 176, 177, 178, 179, 182, 184, 189, 190, 192, 193, 194, 195, 196, 197, 198, 199, 200, 253, 254, 258, 259, 262, 265
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 251 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 75 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 424 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 133 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 356 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 124 matching events found
# Applying baseline correction (mode: mean)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:58: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_norm = mne.concatenate_epochs(conds["normal"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:59: RuntimeWarning: filter_length (331) is longer than the signal (251), distortion is likely. Reduce filter length or filter a longer signal.
#   all_conf = mne.concatenate_epochs(conds["conflict"]).average().filter(l_freq=None, h_freq=10, verbose=False)
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:67: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   plot_compare_evokeds({sess: grand_averages[sess]["normal"] for sess in grand_averages}, picks=channel,
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:69: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   plot_compare_evokeds({sess: grand_averages[sess]["conflict"] for sess in grand_averages}, picks=channel,
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:71: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   plot_compare_evokeds({sess: grand_averages[sess]["difference"] for sess in grand_averages}, picks=channel,
# /Users/yonatan/SSE/prediction_error_EEG/group_analysis.py:78: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
